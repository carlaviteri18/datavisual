# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%html
#   <html>
#   <head>
#     <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#     <script type="text/javascript">
#     // added the 2 following lines to make it run on page load
#     google.charts.load('current', {'packages':['corechart']});
#     google.charts.setOnLoadCallback(drawSheetName);
#     function drawSheetName() {
#       var queryString = encodeURIComponent('SELECT E, COUNT(E) GROUP BY(E)');
#
#       var query = new google.visualization.Query(
#           'https://docs.google.com/spreadsheets/d/18p2wSpQ9Qg3MMzQRBS1tqyuEiKyRg66pQRD7SgomorQ/gviz/tq?sheet=Sheet1&headers=1&tq=' + queryString);
#       query.send(handleSampleDataQueryResponse);
#     }
#
#     function handleSampleDataQueryResponse(response) {
#       if (response.isError()) {
#         alert('Error in query: ' + response.getMessage() + ' ' + response.getDetailedMessage());
#         return;
#       }
#
#       var data = response.getDataTable();
#       var chart = new google.visualization.ColumnChart(document.getElementById('chart_div'));
#       chart.draw(data, { height: 400 });
#     }
#     </script>
#   </head>
#   <body>
#     <div id="chart_div" style="width: 900px; height: 500px"></div>
#   </body>
# </html>
# Out:
#   <html>
#   <head>
#     <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#     <script type="text/javascript">
#     // added the 2 following lines to make it run on page load
#     google.charts.load('current', {'packages':['corechart']});
#     google.charts.setOnLoadCallback(drawSheetName);
#     function drawSheetName() {
#       var queryString = encodeURIComponent('SELECT E, COUNT(E) GROUP BY(E)');
#
#       var query = new google.visualization.Query(
#           'https://docs.google.com/spreadsheets/d/18p2wSpQ9Qg3MMzQRBS1tqyuEiKyRg66pQRD7SgomorQ/gviz/tq?sheet=Sheet1&headers=1&tq=' + queryString);
#       query.send(handleSampleDataQueryResponse);
#     }
#
#     function handleSampleDataQueryResponse(response) {
#       if (response.isError()) {
#         alert('Error in query: ' + response.getMessage() + ' ' + response.getDetailedMessage());
#         return;
#       }
#
#       var data = response.getDataTable();
# ...

# %%
# %%html
#   <html>
#   <head>
#     <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#     <script type="text/javascript">
#     // added the 2 following lines to make it run on page load
#     google.charts.load('current', {'packages':['corechart']});
#     google.charts.setOnLoadCallback(drawSheetName);
#     function drawSheetName() {
#       var queryString = encodeURIComponent('SELECT B, COUNT(B) GROUP BY(B)');
#
#       var query = new google.visualization.Query(
#           'https://docs.google.com/spreadsheets/d/18p2wSpQ9Qg3MMzQRBS1tqyuEiKyRg66pQRD7SgomorQ/gviz/tq?sheet=Sheet1&headers=1&tq=' + queryString);
#       query.send(handleSampleDataQueryResponse);
#     }
#
#     function handleSampleDataQueryResponse(response) {
#       if (response.isError()) {
#         alert('Error in query: ' + response.getMessage() + ' ' + response.getDetailedMessage());
#         return;
#       }
#
#       var data = response.getDataTable();
#       var chart = new google.visualization.ColumnChart(document.getElementById('chart_div'));
#       chart.draw(data, { height: 400 });
#     }
#     </script>
#   </head>
#   <body>
#     <div id="chart_div" style="width: 900px; height: 500px"></div>
#   </body>
# </html>
# Out:
#   <html>
#   <head>
#     <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#     <script type="text/javascript">
#     // added the 2 following lines to make it run on page load
#     google.charts.load('current', {'packages':['corechart']});
#     google.charts.setOnLoadCallback(drawSheetName);
#     function drawSheetName() {
#       var queryString = encodeURIComponent('SELECT B, COUNT(B) GROUP BY(B)');
#
#       var query = new google.visualization.Query(
#           'https://docs.google.com/spreadsheets/d/18p2wSpQ9Qg3MMzQRBS1tqyuEiKyRg66pQRD7SgomorQ/gviz/tq?sheet=Sheet1&headers=1&tq=' + queryString);
#       query.send(handleSampleDataQueryResponse);
#     }
#
#     function handleSampleDataQueryResponse(response) {
#       if (response.isError()) {
#         alert('Error in query: ' + response.getMessage() + ' ' + response.getDetailedMessage());
#         return;
#       }
#
#       var data = response.getDataTable();
# ...

# %%
# %%html
# <html>
# <head>
#   <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#   <script type="text/javascript">
#   google.charts.load('current', {'packages':['corechart']});
#   google.charts.setOnLoadCallback(drawChart);
#
#   function drawChart() {
#     var rawData = [
#       ['Diet Type', 'Triceratops', 'Stegosaurus', 'Brachiosaurus', 'Tyrannosaurus', 'Velociraptor', 'Therizinosaurus', 'Oviraptor'],
#       ['Herbivore', 5, 8, 12, 0, 0, 0, 0],
#       ['Carnivore', 0, 0, 0, 10, 5, 0, 0],
#       ['Omnivore', 0, 0, 0, 0, 0, 7, 3]
#     ];
#
#     var data = google.visualization.arrayToDataTable(rawData);
#
#     var options = {
#       height: 400,
#       legend: { position: 'top' },
#       isStacked: true,
#       colors: ['#3366cc', '#dc3912', '#ff9900', '#109618', '#990099', '#0099c6', '#dd4477'], // changing bar colors
#       hAxis: {
#         title: 'Diet Type',
#       },
#       vAxis: {
#         title: 'Count',
#         minValue: 0
#       }
#     };
#
#     var chart = new google.visualization.ColumnChart(document.getElementById('chart_div'));
#     chart.draw(data, options);
#   }
#   </script>
# </head>
# <body>
#   <div id="chart_div" style="width: 900px; height: 500px"></div>
# </body>
# </html>
# Out:
# <html>
# <head>
#   <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#   <script type="text/javascript">
#   google.charts.load('current', {'packages':['corechart']});
#   google.charts.setOnLoadCallback(drawChart);
#
#   function drawChart() {
#     var rawData = [
#       ['Diet Type', 'Triceratops', 'Stegosaurus', 'Brachiosaurus', 'Tyrannosaurus', 'Velociraptor', 'Therizinosaurus', 'Oviraptor'],
#       ['Herbivore', 5, 8, 12, 0, 0, 0, 0],
#       ['Carnivore', 0, 0, 0, 10, 5, 0, 0],
#       ['Omnivore', 0, 0, 0, 0, 0, 7, 3]
#     ];
#
#     var data = google.visualization.arrayToDataTable(rawData);
#
#     var options = {
#       height: 400,
#       legend: { position: 'top' },
#       isStacked: true,
#       colors: ['#3366cc', '#dc3912', '#ff9900', '#109618', '#990099', '#0099c6', '#dd4477'], // changing bar colors
#       hAxis: {
#         title: 'Diet Type',
#       },
#       vAxis: {
#         title: 'Count',
#         minValue: 0
# ...

# %%
import pandas as pd

# Load the data
url = "https://docs.google.com/spreadsheets/d/18p2wSpQ9Qg3MMzQRBS1tqyuEiKyRg66pQRD7SgomorQ/export?format=csv&gid=1858574533"
df = pd.read_csv(url)

# Calculate IQR
Q1 = df['length(m,fixed)'].quantile(0.25)
Q3 = df['length(m,fixed)'].quantile(0.75)
IQR = Q3 - Q1

# Calculate number of data points
n = len(df)

# Calculate bin size using Freedman-Diaconis rule
bin_size = 2 * IQR / (n ** (1/3))

print("Interquartile Range (IQR):", IQR)
print("Number of data points (n):", n)
print("Ideal bin size according to Freedman-Diaconis rule:", bin_size)
# Out:
# Interquartile Range (IQR): 7.0
# Number of data points (n): 309
# Ideal bin size according to Freedman-Diaconis rule: 2.0708177356573625

# %%
# %%html
# <html>
# <head>
#   <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#   <script type="text/javascript">
#   // added the 2 following lines to make it run on page load
#   google.charts.load('current', {'packages':['corechart']});
#   google.charts.setOnLoadCallback(drawSheetName);
#   function drawSheetName() {
#     var queryString = encodeURIComponent('SELECT K');
#
#     var query = new google.visualization.Query(
#         'https://docs.google.com/spreadsheets/d/18p2wSpQ9Qg3MMzQRBS1tqyuEiKyRg66pQRD7SgomorQ/gviz/tq?sheet=Sheet1&headers=1&tq=' + queryString);
#     query.send(handleSampleDataQueryResponse);
#   }
#
#   function handleSampleDataQueryResponse(response) {
#     if (response.isError()) {
#       alert('Error in query: ' + response.getMessage() + ' ' + response.getDetailedMessage());
#       return;
#     }
#
#     var data = response.getDataTable();
#     var options = {
#       title: 'Dinosaur Lengths (meters) Histogram',
#       legend: { position: 'right' },
#       histogram: { bucketSize: 2.1, minValue: 0, maxValue: 20 },
#       hAxis: { title: 'Length (meters)' },
#       vAxis: { title: 'Count' },
#       colors: ['#FF00FF'], // Change the color to blue
#       width: 900,
#       height: 500
#     };
#     var chart = new google.visualization.Histogram(document.getElementById('chart_div'));
#     chart.draw(data, options);
#   }
#   </script>
# </head>
# <body>
#   <div id="chart_div" style="width: 900px; height: 500px"></div>
# </body>
# </html>
# Out:
# <html>
# <head>
#   <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#   <script type="text/javascript">
#   // added the 2 following lines to make it run on page load
#   google.charts.load('current', {'packages':['corechart']});
#   google.charts.setOnLoadCallback(drawSheetName);
#   function drawSheetName() {
#     var queryString = encodeURIComponent('SELECT K');
#
#     var query = new google.visualization.Query(
#         'https://docs.google.com/spreadsheets/d/18p2wSpQ9Qg3MMzQRBS1tqyuEiKyRg66pQRD7SgomorQ/gviz/tq?sheet=Sheet1&headers=1&tq=' + queryString);
#     query.send(handleSampleDataQueryResponse);
#   }
#
#   function handleSampleDataQueryResponse(response) {
#     if (response.isError()) {
#       alert('Error in query: ' + response.getMessage() + ' ' + response.getDetailedMessage());
#       return;
#     }
#
#     var data = response.getDataTable();
#     var options = {
#       title: 'Dinosaur Lengths (meters) Histogram',
# ...

# %%
# %%html
# <html>
# <head>
#   <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#   <script type="text/javascript">
#     google.charts.load('current', {'packages':['geochart']});
#     google.charts.setOnLoadCallback(drawRegionsMap);
#
#     function drawRegionsMap() {
#       var queryString = encodeURIComponent('SELECT D, COUNT(E) GROUP BY D');
#
#       var query = new google.visualization.Query(
#         'https://docs.google.com/spreadsheets/d/18p2wSpQ9Qg3MMzQRBS1tqyuEiKyRg66pQRD7SgomorQ/gviz/tq?sheet=Sheet1&headers=1&tq=' + queryString);
#       query.send(handleSampleDataQueryResponse);
#     }
#
#     function handleSampleDataQueryResponse(response) {
#       if (response.isError()) {
#         alert('Error in query: ' + response.getMessage() + ' ' + response.getDetailedMessage());
#         return;
#       }
#
#       var data = response.getDataTable();
#       var options = {
#         colorAxis: { colors: ['#F05421', '#880E4F'] }, // Bright magenta to less intense magenta gradient
#         backgroundColor: '#81d4fa', // Light blue background color
#         datalessRegionColor: '#f8bbd0', // Light pink color for regions with no data
#         defaultColor: '#f5f5f5', // Grey color for regions outside the dataset
#         width: 900,
#         height: 500
#       };
#
#       var chart = new google.visualization.GeoChart(document.getElementById('chart_div'));
#
#       chart.draw(data, options);
#     }
#   </script>
# </head>
# <body>
#   <div id="chart_div" style="width: 900px; height: 500px;"></div>
# </body>
# </html>
# Out:
# <html>
# <head>
#   <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#   <script type="text/javascript">
#     google.charts.load('current', {'packages':['geochart']});
#     google.charts.setOnLoadCallback(drawRegionsMap);
#
#     function drawRegionsMap() {
#       var queryString = encodeURIComponent('SELECT D, COUNT(E) GROUP BY D');
#
#       var query = new google.visualization.Query(
#         'https://docs.google.com/spreadsheets/d/18p2wSpQ9Qg3MMzQRBS1tqyuEiKyRg66pQRD7SgomorQ/gviz/tq?sheet=Sheet1&headers=1&tq=' + queryString);
#       query.send(handleSampleDataQueryResponse);
#     }
#
#     function handleSampleDataQueryResponse(response) {
#       if (response.isError()) {
#         alert('Error in query: ' + response.getMessage() + ' ' + response.getDetailedMessage());
#         return;
#       }
#
#       var data = response.getDataTable();
#       var options = {
# ...

# %%
#reworking map

# %%html
<html>
<head>
  <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
  <script type="text/javascript">
    google.charts.load('current', {'packages':['geochart']});
    google.charts.setOnLoadCallback(drawRegionsMap);

    function drawRegionsMap() {
      var queryString = encodeURIComponent('SELECT D, COUNT(E) GROUP BY D');

      var query = new google.visualization.Query(
        'https://docs.google.com/spreadsheets/d/18p2wSpQ9Qg3MMzQRBS1tqyuEiKyRg66pQRD7SgomorQ/gviz/tq?sheet=Sheet1&headers=1&tq=' + queryString);
      query.send(handleSampleDataQueryResponse);
    }

    function handleSampleDataQueryResponse(response) {
      if (response.isError()) {
        alert('Error in query: ' + response.getMessage() + ' ' + response.getDetailedMessage());
        return;
      }

      var data = response.getDataTable();

      // Replace "USA" with "United States"
      for (var i = 0; i < data.getNumberOfRows(); i++) {
        if (data.getValue(i, 0) === "USA") {
          data.setCell(i, 0, "United States");
        }
      }

      var options = {
        colorAxis: { colors: ['#F06292', '#880E4F'] }, // Bright magenta to less intense magenta gradient
        backgroundColor: '#81d4fa', // Light blue background color
        datalessRegionColor: '#f8bbd0', // Light pink color for regions with no data
        defaultColor: '#f5f5f5', // Grey color for regions outside the dataset
        width: 900,
        height: 500
      };

      var chart = new google.visualization.GeoChart(document.getElementById('chart_div'));

      chart.draw(data, options);
    }
  </script>
</head>
<body>
  <div id="chart_div" style="width: 900px; height: 500px;"></div>
</body>
</html>
# Out:
# <html>
# <head>
#   <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#   <script type="text/javascript">
#     google.charts.load('current', {'packages':['geochart']});
#     google.charts.setOnLoadCallback(drawRegionsMap);
#
#     function drawRegionsMap() {
#       var queryString = encodeURIComponent('SELECT D, COUNT(E) GROUP BY D');
#
#       var query = new google.visualization.Query(
#         'https://docs.google.com/spreadsheets/d/18p2wSpQ9Qg3MMzQRBS1tqyuEiKyRg66pQRD7SgomorQ/gviz/tq?sheet=Sheet1&headers=1&tq=' + queryString);
#       query.send(handleSampleDataQueryResponse);
#     }
#
#     function handleSampleDataQueryResponse(response) {
#       if (response.isError()) {
#         alert('Error in query: ' + response.getMessage() + ' ' + response.getDetailedMessage());
#         return;
#       }
#
#       var data = response.getDataTable();
#
#       // Replace "USA" with "United States"
# ...

# %%
# %%html
# <html>
# <head>
#   <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#   <script type="text/javascript">
#     google.charts.load('current', {'packages':['corechart']});
#     google.charts.setOnLoadCallback(drawChart);
#
#     function drawChart() {
#       var queryString = encodeURIComponent('SELECT B, COUNT(B) GROUP BY B PIVOT E');
#
#       var query = new google.visualization.Query(
#           'https://docs.google.com/spreadsheets/d/18p2wSpQ9Qg3MMzQRBS1tqyuEiKyRg66pQRD7SgomorQ/gviz/tq?sheet=Sheet1&headers=1&tq=' + queryString);
#       query.send(handleSampleDataQueryResponse);
#     }
#
#     function handleSampleDataQueryResponse(response) {
#       if (response.isError()) {
#         alert('Error in query: ' + response.getMessage() + ' ' + response.getDetailedMessage());
#         return;
#       }
#
#       var data = response.getDataTable();
#
#       // Adjust chart options
#       var options = {
#         title: 'Dinosaurs by Diet',
#         width: 900,
#         height: 500,
#         legend: { position: 'top', maxLines: 2 }, // Display legend at the top
#         isStacked: true, // Use a stacked bar chart
#         colors: ['#65655E', '#7D80DA', '#B0A3D4', '#CEBACF', '#AA889A', '#835D60'] // Seven colors palette
#       };
#
#       var chart = new google.visualization.BarChart(document.getElementById('chart_div'));
#       chart.draw(data, options);
#     }
#   </script>
# </head>
# <body>
#   <div id="chart_div" style="width: 900px; height: 500px;"></div>
# </body>
# </html>
# Out:
# <html>
# <head>
#   <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#   <script type="text/javascript">
#     google.charts.load('current', {'packages':['corechart']});
#     google.charts.setOnLoadCallback(drawChart);
#
#     function drawChart() {
#       var queryString = encodeURIComponent('SELECT B, COUNT(B) GROUP BY B PIVOT E');
#
#       var query = new google.visualization.Query(
#           'https://docs.google.com/spreadsheets/d/18p2wSpQ9Qg3MMzQRBS1tqyuEiKyRg66pQRD7SgomorQ/gviz/tq?sheet=Sheet1&headers=1&tq=' + queryString);
#       query.send(handleSampleDataQueryResponse);
#     }
#
#     function handleSampleDataQueryResponse(response) {
#       if (response.isError()) {
#         alert('Error in query: ' + response.getMessage() + ' ' + response.getDetailedMessage());
#         return;
#       }
#
#       var data = response.getDataTable();
#
#       // Adjust chart options
#       var options = {
# ...
